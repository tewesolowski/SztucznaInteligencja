# %% [markdown]
# ## Zbiór danych
# - musi się pobrać Zalando Fashion-MNIST
# https://github.com/zalandoresearch/fashion-mnist

# %%
# wczytanie potrzebnych bibliotek
import tensorflow as tf

# wczytanie danych
fashion_mnist = tf.keras.datasets.fashion_mnist
(X_train, y_train), (X_val, y_val) = fashion_mnist.load_data()

print(f'Zbiór uczący: {X_train.shape}, zbiór walidacyjny: {X_val.shape}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Zbiór uczący: (60000, 28, 28), zbiór walidacyjny: (10000, 28, 28)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,7))
plt.imshow(X_train[0], cmap=plt.cm.binary)
plt.colorbar()
plt.show()

# %%
def plot_digit(digit, dem=28, font_size=8):
    max_ax = font_size * dem

    fig = plt.figure(figsize=(10,10))
    plt.xlim([0, max_ax])
    plt.ylim([0, max_ax])
    plt.axis('off')

    for idx in range(dem):
        for jdx in range(dem):
            t = plt.text(idx*font_size, max_ax - jdx*font_size,
                         digit[jdx][idx], fontsize=font_size,
                         color="#000000")
            c = digit[jdx][idx] / 255.
            t.set_bbox(dict(facecolor=(c, c, c), alpha=0.5,
                            edgecolor='#f1f1f1'))

    plt.show()

# %%
plot_digit(X_train[0])

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

plt.figure(figsize=(14,10))
for i in range(40):
    plt.subplot(5, 8, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %% [markdown]
# ## Przygotowanie danych

# %%
X_train = X_train.astype('float32') / 255.0
X_val = X_val.astype('float32') / 255.0

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train, len(class_names))
y_val = to_categorical(y_val, len(class_names))

# %% [markdown]
# ## Pierwsza architektura

# %%
from tensorflow.keras.models import Sequential

model = Sequential()

# %%
from tensorflow.keras.layers import Flatten, add

model.add(Flatten(input_shape=(28, 28)))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# Definiowanie pierwszej warstwy ukrytej

# %%
from tensorflow.keras.layers import Dense

model.add(Dense(128, activation='relu'))

# %% [markdown]
# Definiowanie warstwy wyjściowej

# %%
model.add(Dense(10, activation = 'softmax'))

# %% [markdown]
# Kompilacja modelu

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Podsumowanie modelu

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         100,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Trenowanie modelu

# %%
history = model.fit(X_train,
                    y_train,
                    epochs=10,
                    verbose=1,
                    batch_size = 256,
                    validation_data = (X_val, y_val)
                   )
# Out:
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7243 - loss: 0.8321 - val_accuracy: 0.8278 - val_loss: 0.4832
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8503 - loss: 0.4331 - val_accuracy: 0.8472 - val_loss: 0.4356
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8604 - loss: 0.3879 - val_accuracy: 0.8572 - val_loss: 0.4065
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8732 - loss: 0.3596 - val_accuracy: 0.8595 - val_loss: 0.3957
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8796 - loss: 0.3385 - val_accuracy: 0.8667 - val_loss: 0.3785
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8855 - loss: 0.3214 - val_accuracy: 0.8719 - val_loss: 0.3615
# Epoch 7/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8870 - loss: 0.3145 - val_accuracy: 0.8716 - val_loss: 0.3570
# Epoch 8/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8931 - loss: 0.3011 - val_accuracy: 0.8749 - val_loss: 0.3469
# Epoch 9/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8949 - loss: 0.2872 - val_accuracy: 0.8705 - val_loss: 0.3578
# Epoch 10/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8996 - loss: 0.2769 - val_accuracy: 0.8698 - val_loss: 0.3567

# %% [markdown]
# Wizualizacja z trenowania

# %%
def draw_curves(history, key1='accuracy', ylim1=(0.8, 1.00),
                key2='loss', ylim2=(0.0, 1.0)):
    plt.figure(figsize=(12,4))

    plt.subplot(1, 2, 1)
    plt.plot(history.history[key1], "r--")
    plt.plot(history.history['val_' + key1], "g--")
    plt.ylabel(key1)
    plt.xlabel('Epoch')
    plt.ylim(ylim1)
    plt.legend(['train', 'test'], loc='best')

    plt.subplot(1, 2, 2)
    plt.plot(history.history[key2], "r--")
    plt.plot(history.history['val_' + key2], "g--")
    plt.ylabel(key2)
    plt.xlabel('Epoch')
    plt.ylim(ylim2)
    plt.legend(['train', 'test'], loc='best')

    plt.show()

draw_curves(history, key1='accuracy', ylim1=(0.7, 0.95),
            key2='loss', ylim2=(0.0, 0.8))

# %%
model2 = Sequential()
model2.add(Flatten(input_shape=(28, 28)))
model2.add(Dense(128, activation='relu')) #FIX model -> model2
model2.add(Dense(10, activation = 'softmax'))

model2.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
model2.summary()

history2 = model2.fit(X_train,
                    y_train,
                    epochs=50,
                    verbose=1,
                    batch_size = 256,
                    validation_data = (X_val, y_val)
                   )

draw_curves(history2, key1='accuracy', ylim1=(0.7, 0.95),
            key2='loss', ylim2=(0.0, 0.8))
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         100,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 305,312 (1.16 MB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 203,542 (795.09 KB)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │         100,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7121 - loss: 0.8615 - val_accuracy: 0.8363 - val_loss: 0.4737
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8476 - loss: 0.4377 - val_accuracy: 0.8475 - val_loss: 0.4326
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8593 - loss: 0.3963 - val_accuracy: 0.8553 - val_loss: 0.4176
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8703 - loss: 0.3682 - val_accuracy: 0.8610 - val_loss: 0.3965
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8803 - loss: 0.3382 - val_accuracy: 0.8664 - val_loss: 0.3850
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8830 - loss: 0.3275 - val_accuracy: 0.8628 - val_loss: 0.3864
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8896 - loss: 0.3110 - val_accuracy: 0.8709 - val_loss: 0.3558
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8938 - loss: 0.2980 - val_accuracy: 0.8765 - val_loss: 0.3507
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8930 - loss: 0.2934 - val_accuracy: 0.8725 - val_loss: 0.3498
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8967 - loss: 0.2857 - val_accuracy: 0.8767 - val_loss: 0.3374
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9019 - loss: 0.2735 - val_accuracy: 0.8745 - val_loss: 0.3443
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9037 - loss: 0.2658 - val_accuracy: 0.8760 - val_loss: 0.3425
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9062 - loss: 0.2546 - val_accuracy: 0.8804 - val_loss: 0.3294
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9064 - loss: 0.2542 - val_accuracy: 0.8807 - val_loss: 0.3324
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9122 - loss: 0.2432 - val_accuracy: 0.8740 - val_loss: 0.3448
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9159 - loss: 0.2346 - val_accuracy: 0.8821 - val_loss: 0.3283
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9134 - loss: 0.2345 - val_accuracy: 0.8828 - val_loss: 0.3324
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9176 - loss: 0.2289 - val_accuracy: 0.8843 - val_loss: 0.3284
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9189 - loss: 0.2221 - val_accuracy: 0.8815 - val_loss: 0.3364
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9196 - loss: 0.2203 - val_accuracy: 0.8846 - val_loss: 0.3241
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9230 - loss: 0.2108 - val_accuracy: 0.8801 - val_loss: 0.3331
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9226 - loss: 0.2081 - val_accuracy: 0.8860 - val_loss: 0.3232
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9235 - loss: 0.2078 - val_accuracy: 0.8853 - val_loss: 0.3289
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9253 - loss: 0.2001 - val_accuracy: 0.8869 - val_loss: 0.3161
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9262 - loss: 0.2012 - val_accuracy: 0.8822 - val_loss: 0.3369
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9284 - loss: 0.1961 - val_accuracy: 0.8872 - val_loss: 0.3351
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9314 - loss: 0.1847 - val_accuracy: 0.8848 - val_loss: 0.3317
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9295 - loss: 0.1918 - val_accuracy: 0.8878 - val_loss: 0.3261
# Epoch 29/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9335 - loss: 0.1830 - val_accuracy: 0.8898 - val_loss: 0.3222
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9369 - loss: 0.1792 - val_accuracy: 0.8836 - val_loss: 0.3358
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9358 - loss: 0.1750 - val_accuracy: 0.8867 - val_loss: 0.3259
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9368 - loss: 0.1739 - val_accuracy: 0.8893 - val_loss: 0.3297
# Epoch 33/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9376 - loss: 0.1732 - val_accuracy: 0.8893 - val_loss: 0.3326
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9386 - loss: 0.1699 - val_accuracy: 0.8857 - val_loss: 0.3435
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9412 - loss: 0.1630 - val_accuracy: 0.8883 - val_loss: 0.3358
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9427 - loss: 0.1598 - val_accuracy: 0.8890 - val_loss: 0.3395
# Epoch 37/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9431 - loss: 0.1588 - val_accuracy: 0.8866 - val_loss: 0.3492
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9448 - loss: 0.1538 - val_accuracy: 0.8873 - val_loss: 0.3419
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9470 - loss: 0.1501 - val_accuracy: 0.8867 - val_loss: 0.3415
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9467 - loss: 0.1477 - val_accuracy: 0.8867 - val_loss: 0.3452
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9471 - loss: 0.1441 - val_accuracy: 0.8842 - val_loss: 0.3642
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9450 - loss: 0.1549 - val_accuracy: 0.8875 - val_loss: 0.3537
# Epoch 43/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9478 - loss: 0.1413 - val_accuracy: 0.8891 - val_loss: 0.3489
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9487 - loss: 0.1411 - val_accuracy: 0.8840 - val_loss: 0.3571
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9510 - loss: 0.1345 - val_accuracy: 0.8827 - val_loss: 0.3630
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9493 - loss: 0.1409 - val_accuracy: 0.8893 - val_loss: 0.3565
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9518 - loss: 0.1339 - val_accuracy: 0.8898 - val_loss: 0.3597
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9540 - loss: 0.1272 - val_accuracy: 0.8874 - val_loss: 0.3664
# Epoch 49/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9544 - loss: 0.1270 - val_accuracy: 0.8892 - val_loss: 0.3661
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9552 - loss: 0.1268 - val_accuracy: 0.8820 - val_loss: 0.3786

# %% [markdown]
# Predykcja

# %%
y_train_pred = model.predict(X_train) #TRY model -> model2
y_val_pred = model.predict(X_val) #TRY model -> model2
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
import numpy as np #FIX added

def plot_value_img(i, predictions, true_label, img):
    predictions, true_label, img = predictions[i], true_label[i], img[i]
    predicted_label = np.argmax(predictions)
    true_value = np.argmax(true_label)

    plt.figure(figsize=(12,5))

    plt.subplot(1, 2, 1)

    plt.yticks(np.arange(len(class_names)), class_names)
    thisplot = plt.barh(range(10), predictions, color="gray")
    thisplot[predicted_label].set_color('r')
    thisplot[true_value].set_color('g')

    plt.subplot(1, 2, 2)

    plt.imshow(img, cmap=plt.cm.binary)
    if predicted_label == true_value:
        color = 'green'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions),
                                class_names[true_value]),
                                color=color)
    plt.show()

plot_value_img(1, y_val_pred,  y_val, X_val) #FIX pierwszy parametr to indeks analizowanego obrazu 1 4 12
